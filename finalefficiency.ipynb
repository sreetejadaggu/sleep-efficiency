# %%
import pandas as pd
d=pd.read_csv('/content/modifiedAIML 3.csv')
print(d)
# Out:
#       ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0      1   65       0               6                 1                     1
# 1      2   69       1               7                 1                    24
# 2      3   40       0               8                 0                    20
# 3      4   40       0               6                 1                    28
# 4      5   57       1               8                 1                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27       0               7                 1                    25
# 448  449   52       1               6                 1                    28
# 449  450   40       0               8                 0                    20
# 450  451   45       1               7                 1                     1
# 451  452    1       1               7                 1                    22
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      10           0
# 1                       28                      53           3
# 2                       70                      10           1
# 3                       25                      52           3
# 4                       55                       1           3
# ..                     ...                     ...         ...
# 447                     57                      21           0
# 448                     57                      21           4
# 449                     30                      48           1
# 450                     70                      10           3
# 451                     23                      54           1
#
#      Caffeine consumption  Alcohol consumption  Smoking status  \
# 0                       0                    0               1
# 1                       0                    3               1
# 2                       0                    0               0
# 3                      50                    5               1
# 4                       0                    3               0
# ..                    ...                  ...             ...
# 447                     0                    0               0
# 448                    25                    0               0
# 449                     0                    3               1
# 450                     0                    0               0
# 451                    50                    1               0
#
#      Exercise frequency
# 0                     3
# 1                     3
# 2                     3
# 3                     1
# 4                     3
# ..                  ...
# 447                   5
# 448                   3
# 449                   0
# 450                   3
# 451                   1
#
# [452 rows x 13 columns]

# %%
d.head()
# Out:
#    ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0   1   65       0               6                 1                     1
# 1   2   69       1               7                 1                    24
# 2   3   40       0               8                 0                    20
# 3   4   40       0               6                 1                    28
# 4   5   57       1               8                 1                    27
#
#    Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                     70                      10           0
# 1                     28                      53           3
# 2                     70                      10           1
# 3                     25                      52           3
# 4                     55                       1           3
#
#    Caffeine consumption  Alcohol consumption  Smoking status  \
# 0                     0                    0               1
# 1                     0                    3               1
# 2                     0                    0               0
# 3                    50                    5               1
# 4                     0                    3               0
#
#    Exercise frequency
# 0                   3
# 1                   3
# 2                   3
# 3                   1
# 4                   3

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    int64
#  3   Sleep duration          452 non-null    int64
#  4   Sleep efficiency        452 non-null    int64
#  5   REM sleep percentage    452 non-null    int64
#  6   Deep sleep percentage   452 non-null    int64
#  7   Light sleep percentage  452 non-null    int64
#  8   Awakenings              452 non-null    int64
#  9   Caffeine consumption    452 non-null    int64
#  10  Alcohol consumption     452 non-null    int64
#  11  Smoking status          452 non-null    int64
#  12  Exercise frequency      452 non-null    int64
# dtypes: int64(13)
# memory usage: 46.0 KB

# %%
import matplotlib.pyplot as plt

# %%
x1=d['Sleep duration']
y=d['Sleep efficiency']
plt.scatter(x1,y)

# %%
x2=d['REM sleep percentage']
y=d['Sleep efficiency']
plt.scatter(x2,y)

# %%
x3=d['Deep sleep percentage']
y=d['Sleep efficiency']
plt.scatter(x3,y)

# %%
x4=d['Light sleep percentage']
y=d['Sleep efficiency']
plt.scatter(x4,y)

# %%
x5=d['Awakenings']
y=d['Sleep efficiency']
plt.scatter(x5,y)

# %%
x6=d['Caffeine consumption']
y=d['Sleep efficiency']
plt.scatter(x6,y)

# %%
x7=d['Alcohol consumption']
y=d['Sleep efficiency']
plt.scatter(x7,y)

# %%
x8=d['Smoking status']
y=d['Sleep efficiency']
plt.scatter(x8,y)

# %%
x9=d['Exercise frequency']
y=d['Sleep efficiency']
plt.scatter(x9,y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def heat_map(df):
  plt.figure(figsize=(6,4))
  sns.heatmap(df.isnull())
  return plt.show()

heat_map(d)

# %%
import seaborn as sns
sns.boxplot(data=d,x='Sleep efficiency')
# Out:
# <Axes: xlabel='Sleep efficiency'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='REM sleep percentage')
# Out:
# <Axes: xlabel='REM sleep percentage'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Sleep duration')
# Out:
# <Axes: xlabel='Sleep duration'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Deep sleep percentage')
# Out:
# <Axes: xlabel='Deep sleep percentage'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Light sleep percentage')
# Out:
# <Axes: xlabel='Light sleep percentage'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Awakenings')
# Out:
# <Axes: xlabel='Awakenings'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Caffeine consumption')
# Out:
# <Axes: xlabel='Caffeine consumption'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Alcohol consumption')
# Out:
# <Axes: xlabel='Alcohol consumption'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Exercise frequency')
# Out:
# <Axes: xlabel='Exercise frequency'>

# %%
from matplotlib import pyplot as plt
fig, ax=plt.subplots(1,2)
sns.histplot(data=d ,x=d['Sleep duration'],hue=d['Sleep efficiency'], kde=True ,ax=ax[0] )
sns.boxplot(x=d['Deep sleep percentage'],y=d['REM sleep percentage'] ,ax=ax[1])
# Out:
# <Axes: xlabel='Deep sleep percentage', ylabel='REM sleep percentage'>

# %%
corr_matrix=d.corr()
print(corr_matrix)
# Out:
#                               ID       Age    Gender  Sleep duration  \
# ID                      1.000000  0.029888 -0.029689        0.046065
# Age                     0.029888  1.000000  0.240717       -0.065807
# Gender                 -0.029689  0.240717  1.000000       -0.057441
# Sleep duration          0.046065 -0.065807 -0.057441        1.000000
# Sleep efficiency       -0.014226 -0.039853  0.026818        0.033992
# REM sleep percentage    0.017654  0.050790 -0.182017       -0.023779
# Deep sleep percentage  -0.018324  0.042183  0.061795       -0.023985
# Light sleep percentage  0.004706 -0.021113 -0.005848        0.008609
# Awakenings             -0.059804 -0.020559  0.072378        0.005913
# Caffeine consumption   -0.034352 -0.136024 -0.236264       -0.032764
# Alcohol consumption     0.060889 -0.036540  0.027437        0.019896
# Smoking status          0.004929 -0.035111  0.108921        0.011892
# Exercise frequency     -0.007526  0.102253  0.222407       -0.068111
#
#                         Sleep efficiency  REM sleep percentage  \
# ID                             -0.014226              0.017654
# Age                            -0.039853              0.050790
# Gender                          0.026818             -0.182017
# Sleep duration                  0.033992             -0.023779
# Sleep efficiency                1.000000             -0.071764
# REM sleep percentage           -0.071764              1.000000
# Deep sleep percentage          -0.123964             -0.119824
# Light sleep percentage          0.104246             -0.059060
# Awakenings                      0.002537             -0.055138
# Caffeine consumption           -0.003224              0.096779
# Alcohol consumption             0.055838             -0.073729
# Smoking status                  0.034857             -0.001079
# Exercise frequency              0.024688             -0.122729
#
#                         Deep sleep percentage  Light sleep percentage  \
# ID                                  -0.018324                0.004706
# Age                                  0.042183               -0.021113
# Gender                               0.061795               -0.005848
# Sleep duration                      -0.023985                0.008609
# Sleep efficiency                    -0.123964                0.104246
# REM sleep percentage                -0.119824               -0.059060
# Deep sleep percentage                1.000000               -0.928749
# Light sleep percentage              -0.928749                1.000000
# Awakenings                          -0.276470                0.286395
# Caffeine consumption                 0.000659               -0.089671
# Alcohol consumption                 -0.392713                0.393283
# Smoking status                      -0.251615                0.242589
# Exercise frequency                   0.161514               -0.128195
#
#                         Awakenings  Caffeine consumption  Alcohol consumption  \
# ID                       -0.059804             -0.034352             0.060889
# Age                      -0.020559             -0.136024            -0.036540
# Gender                    0.072378             -0.236264             0.027437
# Sleep duration            0.005913             -0.032764             0.019896
# Sleep efficiency          0.002537             -0.003224             0.055838
# REM sleep percentage     -0.055138              0.096779            -0.073729
# Deep sleep percentage    -0.276470              0.000659            -0.392713
# Light sleep percentage    0.286395             -0.089671             0.393283
# Awakenings                1.000000             -0.116077             0.184091
# Caffeine consumption     -0.116077              1.000000            -0.139740
# Alcohol consumption       0.184091             -0.139740             1.000000
# Smoking status           -0.008590             -0.006758             0.058403
# Exercise frequency       -0.226378             -0.076590            -0.047311
#
#                         Smoking status  Exercise frequency
# ID                            0.004929           -0.007526
# Age                          -0.035111            0.102253
# Gender                        0.108921            0.222407
# Sleep duration                0.011892           -0.068111
# Sleep efficiency              0.034857            0.024688
# REM sleep percentage         -0.001079           -0.122729
# Deep sleep percentage        -0.251615            0.161514
# Light sleep percentage        0.242589           -0.128195
# Awakenings                   -0.008590           -0.226378
# Caffeine consumption         -0.006758           -0.076590
# Alcohol consumption           0.058403           -0.047311
# Smoking status                1.000000           -0.079376
# Exercise frequency           -0.079376            1.000000

# %%
cov_matrix=pd.DataFrame.cov(d)
sns.heatmap(cov_matrix,annot=True,fmt='g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
#logistic regression
x=d.iloc[:,:-1].values
y=d.iloc[:,-1:].values

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.25, random_state = 0)#42

# %%
#Normalising the data - Standard Scalar
from sklearn.preprocessing import StandardScaler
sst=StandardScaler()
X_train=sst.fit_transform(xtrain)   #Normalizing
X_test=sst.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state = 0)

# %%
model.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
ypred=model.predict(xtest)

# %%
ypred
# Out:
# array([3, 2, 0, 0, 1, 1, 1, 1, 0, 3, 1, 3, 0, 3, 1, 1, 3, 3, 1, 0, 3, 1,
#        0, 3, 0, 3, 3, 0, 1, 1, 0, 3, 0, 0, 0, 3, 0, 3, 1, 0, 3, 5, 0, 4,
#        0, 3, 1, 3, 3, 3, 3, 0, 1, 0, 1, 4, 1, 1, 0, 3, 3, 1, 3, 4, 1, 3,
#        1, 0, 0, 1, 3, 1, 0, 3, 1, 0, 4, 3, 0, 1, 0, 1, 3, 0, 1, 3, 0, 1,
#        3, 3, 0, 0, 3, 3, 1, 3, 3, 3, 0, 3, 0, 3, 1, 3, 3, 3, 3, 1, 3, 3,
#        3, 1, 3])

# %%
xtest
# Out:
# array([[  1,  56,   1, ...,   0,   2,   1],
#        [ 55,   1,   1, ...,   0,   3,   0],
#        [299,  35,   0, ...,  25,   1,   1],
#        ...,
#        [375,  65,   1, ...,  25,   1,   0],
#        [ 23,  29,   0, ...,  75,   0,   0],
#        [ 69,  46,   1, ...,   0,   0,   0]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest, ypred)
print ("Confusion Matrix : \n", cm)
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(ytest, ypred))
# Out:
# Confusion Matrix :
#  [[ 7  2  0  7  1  1]
#  [ 9 15  0  8  0  0]
#  [ 4  8  0  5  0  0]
#  [ 6  3  1 20  3  0]
#  [ 4  2  0  3  0  0]
#  [ 1  1  0  2  0  0]]
# Accuracy :  0.37168141592920356

# %%
model.score(x,y)
# Out:
# 0.4557522123893805

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
#normalizing(to transform features to be o a similar scale) the data-standardscaler
# standardscaler it helps converting all numerical values into the one range
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(xtrain)#normalizing
xtest = sc_x.transform(xtest)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=20) #20 is k value

# %%
knn.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=20)

# %%
y_pred = model.predict(xtest)

# %%
print("predicted value for training value",knn.score(xtrain,ytrain))
print("predicted value for testing value",knn.score(xtest,ytest))
print(" accuracy value",knn.score(sc_x.transform(x),y))
# Out:
# predicted value for training value 0.528023598820059
# predicted value for testing value 0.3805309734513274
#  accuracy value 0.4911504424778761

# %%
from sklearn.metrics import confusion_matrix
knns=confusion_matrix(ytest,y_pred)
print("Confusion matrix:\n",knns)
# Out:
# Confusion matrix:
#  [[ 6  1  1  6  1  3]
#  [ 4  7  2  9  8  2]
#  [ 2  5  3  2  3  2]
#  [ 4  2  3 15  6  3]
#  [ 3  0  1  0  4  1]
#  [ 0  0  0  0  3  1]]

# %%
from sklearn import svm
SVM= svm.SVC()

# %%
SVM.fit(xtrain, ytrain)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
print("Training Accuracy",SVM.score(xtrain,ytrain))
print("Testing Accuracy",SVM.score(xtest,ytest))
print("Overall Accuracy:",SVM.score(sc_x.transform(x),y))
# Out:
# Training Accuracy 0.6873156342182891
# Testing Accuracy 0.4336283185840708
# Overall Accuracy: 0.6238938053097345

# %%
y_pred=SVM.predict(xtest)
y_pred
# Out:
# array([3, 2, 0, 0, 3, 3, 1, 0, 0, 0, 1, 0, 0, 3, 1, 3, 3, 0, 3, 1, 3, 3,
#        0, 3, 0, 3, 3, 0, 3, 1, 1, 3, 0, 0, 3, 3, 3, 3, 1, 3, 3, 0, 0, 4,
#        3, 3, 0, 0, 3, 4, 0, 3, 1, 1, 1, 1, 3, 4, 0, 3, 0, 1, 3, 1, 1, 0,
#        3, 1, 3, 4, 0, 1, 0, 4, 1, 3, 1, 3, 3, 1, 3, 1, 0, 0, 3, 3, 0, 1,
#        3, 0, 4, 0, 0, 0, 1, 3, 3, 3, 0, 3, 0, 0, 1, 0, 0, 0, 3, 1, 3, 0,
#        3, 1, 3])

# %%
from sklearn.metrics import confusion_matrix
SVMS=confusion_matrix(ytest,y_pred)
print("Confusion matrix:\n",SVMS)
# Out:
# Confusion matrix:
#  [[12  0  0  5  1  0]
#  [ 6 15  0 10  1  0]
#  [ 3  5  0  9  0  0]
#  [ 9  4  1 19  0  0]
#  [ 4  1  0  1  3  0]
#  [ 3  0  0  0  1  0]]

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
print("Training Accuracy",dtc.score(xtrain,ytrain))
print("Testing Accuracy",dtc.score(xtest,ytest))
print("Overall Accuracy:",dtc.score(sst.transform(x),y))
# Out:
# Training Accuracy 1.0
# Testing Accuracy 0.6106194690265486
# Overall Accuracy: 0.9026548672566371

# %%
y_pred=dtc.predict(xtest)
y_pred
# Out:
# array([3, 3, 0, 0, 0, 0, 4, 1, 1, 1, 4, 1, 5, 3, 1, 2, 4, 0, 3, 0, 4, 2,
#        0, 1, 0, 3, 2, 4, 4, 2, 1, 2, 0, 0, 3, 0, 3, 3, 1, 2, 2, 0, 0, 0,
#        0, 3, 1, 3, 0, 4, 4, 4, 1, 1, 1, 3, 1, 2, 4, 3, 0, 2, 1, 3, 2, 0,
#        3, 1, 0, 1, 2, 0, 0, 1, 1, 2, 3, 3, 2, 1, 3, 1, 3, 2, 2, 3, 0, 2,
#        3, 3, 4, 0, 0, 4, 1, 0, 1, 3, 3, 1, 0, 4, 1, 1, 4, 3, 4, 1, 3, 3,
#        3, 0, 3])

# %%
from sklearn.metrics import confusion_matrix
dtcs=confusion_matrix(ytest,y_pred)
print("Confusion matrix:\n",dtcs)
# Out:
# Confusion matrix:
#  [[14  2  0  2  0  0]
#  [ 4 18  2  3  5  0]
#  [ 4  1 11  1  0  0]
#  [ 4  2  2 20  5  0]
#  [ 1  3  0  0  5  0]
#  [ 0  0  1  2  0  1]]

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Training Accuracy",dtc.score(xtrain,ytrain))
print("Testing Accuracy",dtc.score(xtest,ytest))
print("Overall Accuracy:",dtc.score(sc_x.transform(x),y))
# Out:
# Training Accuracy 1.0
# Testing Accuracy 0.6106194690265486
# Overall Accuracy: 0.9026548672566371
